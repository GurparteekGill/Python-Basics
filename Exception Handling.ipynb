# %% [markdown]
# # Exception Handling
# try and except
# The basic terminology and syntax used to handle errors in Python is the try and except statements. The code which can cause an exception to occue is put in the try block and the handling of the exception is the implemented in the except block of code. The syntax form is:
#
#
# We can also just check for any exception with just using except: To get a better understanding of all this lets check out an example: We will look at some code that opens and writes a file:

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3532/2354412189.py in <module>
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
try:
    1/0

except ZeroDivisionError:
     print('exception occured')
# Out:
# exception occured

# %%
print("Start")

1/0

print("End ")
# Out:
# Start
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3532/4068015220.py in <module>
#       1 print("Start")
#       2
# ----> 3 1/0
#       4
#       5 print("End ")
#
# ZeroDivisionError: division by zero

# %%
print("Start")
try :
   1/0

except ZeroDivisionError:
    print("Zero divide error")

print("End ")
# Out:
# Start
# Zero divide error
# End

# %%
# Example 2
a=[23,34,56]

# %%
a[15]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3532/1253830251.py in <module>
# ----> 1 a[15]
#
# IndexError: list index out of range

# %%
print("Start")
try :
   a[15]

except IndexError:
    print("Index Error")

print("End ")
# Out:
# Start
# Index Error
# End

# %% [markdown]
# ![image.png](attachment:image.png)# Types of excemptions such as Index Error or Zero divdid error
